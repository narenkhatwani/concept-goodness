# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from itertools import product

# %% [markdown]
# ## Shortlisted 100 concepts

# %%
data = pd.read_csv('survey.csv')  # Your dataset with all the columns

# %%
data.head(2)
# Out:
#         CUI   English Term                         Semantic Type  \
# 0  C2700217     functional  Conceptual Entity,Functional Concept
# 1  C0680730  determination   Governmental or Regulatory Activity
#
#   German Equivalent  Translation Quality Score  Frequency of Occurrence  \
# 0        funktional                        1.0                 16056760
# 1        Bestimmung                        1.0                 12611783
#
#    Word_Count  Normalized Word Count  Valid Medical Concept       POS Tags  \
# 0           1                   0.98                   True  ['adjective']
# 1           1                   0.98                   True       ['noun']
#
#    Combination Score  Frequency of Occurrence Score  Goodness Score
# 0                0.3                       0.604134        0.687034
# 1                0.4                       0.474517        0.684629

# %% [markdown]
# ## Dentist's Baseline

# %%
survey_results = pd.read_csv('survey_results.csv')  # Dentist's ratings

# %%
survey_results.head(2)
# Out:
#                                              concept rating
# 0                            tobacco smoke pollution    Bad
# 1  obstetric goals: ensuring proper intrauterine ...   Good

# %% [markdown]
# ## Trying out all the combinations (Grid Search)

# %%
# Map dentist's ratings to numeric values
rating_map = {'Good': 1, 'Moderate': 0.5, 'Bad': 0}
survey_results['Rating'] = survey_results['rating'].map(rating_map)

# Merge survey results with your dataset on the concept name or identifier
merged_data = pd.merge(data, survey_results, left_on='English Term', right_on='concept')

# %%
merged_data
# Out:
#          CUI                                       English Term  \
# 0   C5652313                             vertebrata cymatophila
# 1   C0042567                               subphylum vertebrata
# 2   C0086418                                     human, general
# 3   C0086418                                      man and woman
# 4   C0086418                   human - origin (qualifier value)
# 5   C0040334                            tobacco smoke pollution
# 6   C0220781                                          synthesis
# 7   C0700276                                            anatomy
# 8   C1705428                                              group
# 9   C0564500        phobic avoidance - mental defence mechanism
# 10  C5566302  post-amputation estimated body weight (observa...
# 11  C0564501  primitive idealisation - mental defence mechanism
# 12  C2127370                redness under outer lower eyelid oS
# 13  C3270653  regulation of acetyl-CoA:oxaloacetate acetyltr...
# 14  C2891441  scooter (nonmotorized) colliding with stationa...
# 15  C1546439               some, but not all, results available
# 16  C1154362   up regulation of female receptivity, post-mating
#
#                      Semantic Type  \
# 0                       Vertebrate
# 1                       Vertebrate
# 2                            Human
# 3                            Human
# 4                            Human
# 5   Environmental Effect of Humans
# 6                Biologic Function
# 7             Anatomical Structure
# 8                Conceptual Entity
# 9                   Mental Process
# 10              Organism Attribute
# 11                  Mental Process
# 12                 Sign or Symptom
# 13              Molecular Function
# 14             Injury or Poisoning
# 15                 Idea or Concept
# 16               Organism Function
#
#                                     German Equivalent  \
# 0                                   Wirbelkomatophila
# 1                                     Subphylumwirbel
# 2                                   Mensch, allgemein
# 3                                       Mann und Frau
# 4              Mensch - Ursprung (Qualifikationswert)
# 5                             Tabakrauchverschmutzung
# 6                                            Synthese
# 7                                            Anatomie
# 8                                              Gruppe
# 9   Phobische Vermeidung - Mechanismus zur mentale...
# 10  Nach dem Amt geschätztes Körpergewicht (beobac...
# 11  Primitive Idealisierung - Mechanismus zur ment...
# 12  Rötung unter dem äußeren unteren Augenlid -Bet...
# 13  Regulation von Acetyl-CoA: Oxaloacetat Acetylt...
# 14  Scooter (nicht motorisiert) kollidiert mit sta...
# 15  Einige, aber nicht alle verfügbaren Ergebnisse...
# 16  Aufregulierung der weiblichen Empfänglichkeit,...
#
#     Translation Quality Score  Frequency of Occurrence  Word_Count  \
# 0                         1.0                 26563041           2
# 1                         1.0                 26562951           2
# 2                         1.0                 22279537           2
# 3                         1.0                 22235747           3
# 4                         1.0                 22234334           5
# 5                         1.0                    15926           3
# 6                         1.0                  8065385           1
# 7                         1.0                  5801874           1
# 8                         1.0                  5672619           1
# 9                         0.0                        5           6
# 10                        0.0                        1           6
# 11                        0.0                        4           6
# 12                        0.0                        0           6
# 13                        0.0                        0           6
# 14                        0.0                        0           6
# 15                        0.0                        0           6
# 16                        0.0                        5           6
#
#     Normalized Word Count  Valid Medical Concept                  POS Tags  \
# 0                    0.96                  False                        []
# 1                    0.96                  False                        []
# 2                    0.96                  False                        []
# 3                    0.94                  False                        []
# 4                    0.90                  False                        []
# 5                    0.94                   True  ['noun', 'verb', 'noun']
# 6                    0.98                   True                  ['noun']
# 7                    0.98                   True                  ['noun']
# 8                    0.98                   True                  ['noun']
# 9                    0.88                  False                        []
# 10                   0.88                  False                        []
# 11                   0.88                  False                        []
# 12                   0.88                  False                        []
# 13                   0.88                  False                        []
# 14                   0.88                  False                        []
# 15                   0.88                  False                        []
# 16                   0.88                  False                        []
#
#     Combination Score  Frequency of Occurrence Score  Goodness Score  \
# 0                0.00                       0.999432        0.691858
# 1                0.00                       0.999428        0.691857
# 2                0.00                       0.838265        0.651566
# 3                0.00                       0.836618        0.647154
# 4                0.00                       0.836565        0.639141
# 5                0.75                       0.000599        0.663150
# 6                0.40                       0.303459        0.641865
# 7                0.40                       0.218295        0.620574
# 8                0.40                       0.213432        0.619358
# 9                0.00                       0.000000        0.176000
# 10               0.00                       0.000000        0.176000
# 11               0.00                       0.000000        0.176000
# 12               0.00                       0.000000        0.176000
# 13               0.00                       0.000000        0.176000
# 14               0.00                       0.000000        0.176000
# 15               0.00                       0.000000        0.176000
# 16               0.00                       0.000000        0.176000
#
#                                               concept    rating  Rating
# 0                              vertebrata cymatophila  Moderate     0.5
# 1                                subphylum vertebrata  Moderate     0.5
# 2                                      human, general      Good     1.0
# 3                                       man and woman      Good     1.0
# 4                    human - origin (qualifier value)      Good     1.0
# 5                             tobacco smoke pollution       Bad     0.0
# 6                                           synthesis      Good     1.0
# 7                                             anatomy      Good     1.0
# 8                                               group      Good     1.0
# 9         phobic avoidance - mental defence mechanism  Moderate     0.5
# 10  post-amputation estimated body weight (observa...  Moderate     0.5
# 11  primitive idealisation - mental defence mechanism      Good     1.0
# 12                redness under outer lower eyelid oS       Bad     0.0
# 13  regulation of acetyl-CoA:oxaloacetate acetyltr...  Moderate     0.5
# 14  scooter (nonmotorized) colliding with stationa...       Bad     0.0
# 15               some, but not all, results available       Bad     0.0
# 16   up regulation of female receptivity, post-mating  Moderate     0.5

# %% [markdown]
# ## Step 2: Define the Objective
#
# Define a function to calculate the goodness scores using different weights and a loss function to evaluate the alignment:

# %%
def calculate_goodness_scores(df, weights):
    return (
        df['Combination Score'] * weights['Combination Score'] +
        df['Normalized Word Count'] * weights['Normalized Word Count'] +
        df['Translation Quality Score'] * weights['Translation Quality Score'] +
        df['Frequency of Occurrence Score'] * weights['Frequency of Occurrence Score']
    )

def loss_function(predicted_scores, actual_ratings):
    return mean_squared_error(predicted_scores, actual_ratings)

# %% [markdown]
# ## Perform Grid Search
#
# Define the range for the weights and perform a grid search to find the best combination:

# %%
# Define the range for the weights
weight_range = np.linspace(0, 1, 11)
weight_combinations = list(product(weight_range, repeat=4))

# Filter out invalid combinations (weights must sum to 1)
valid_weight_combinations = [comb for comb in weight_combinations if np.isclose(sum(comb), 1)]

# Grid search
best_loss = float('inf')
best_weights = None

for weights in valid_weight_combinations:
    weight_dict = {
        'Combination Score': weights[0],
        'Normalized Word Count': weights[1],
        'Translation Quality Score': weights[2],
        'Frequency of Occurrence Score': weights[3]
    }
    predicted_scores = calculate_goodness_scores(merged_data, weight_dict)
    loss = loss_function(predicted_scores, merged_data['Rating'])
    if loss < best_loss:
        best_loss = loss
        best_weights = weight_dict

print(f"Best Weights: {best_weights}")
print(f"Best Loss: {best_loss}")
# Out:
# Best Weights: {'Combination Score': 0.1, 'Normalized Word Count': 0.4, 'Translation Quality Score': 0.2, 'Frequency of Occurrence Score': 0.30000000000000004}
# Best Loss: 0.1147805475393041

# %% [markdown]
# ## No of valid combinations

# %%
# Define the range for the weights
weight_range = np.linspace(0, 1, 11)

# Generate all possible combinations
weight_combinations = list(product(weight_range, repeat=4))

# Filter out invalid combinations (weights must sum to 1)
valid_weight_combinations = [comb for comb in weight_combinations if np.isclose(sum(comb), 1)]

print(f"Total combinations: {len(weight_combinations)}")
print(f"Valid combinations: {len(valid_weight_combinations)}")
# Out:
# Total combinations: 14641
# Valid combinations: 286

# %% [markdown]
# ## Bayesian Optimization

# %%
pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting pyaml>=16.9
#   Downloading pyaml-24.7.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-optimize) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-optimize) (1.10.0)
# Requirement already satisfied: joblib>=0.11 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-optimize) (1.1.1)
# Requirement already satisfied: packaging>=21.3 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-optimize) (22.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-optimize) (1.2.1)
# Requirement already satisfied: PyYAML in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/narenkhatwani/anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->scikit-optimize) (2.2.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.7.0 scikit-optimize-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Dr Koppikar

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from skopt import gp_minimize
from skopt.space import Real

# Load the survey results
survey_results = pd.read_csv('survey_results.csv')  # Dentist's ratings
data = pd.read_csv('survey.csv')  # Your dataset with all the columns

# Map dentist's ratings to numeric values
rating_map = {'Good': 1, 'Moderate': 0.5, 'Bad': 0}
survey_results['Rating'] = survey_results['rating'].map(rating_map)

# Merge survey results with your dataset on the concept name or identifier
merged_data = pd.merge(data, survey_results, left_on='English Term', right_on='concept')

# Function to calculate goodness scores
def calculate_goodness_scores(weights):
    scores = (
        merged_data['Combination Score'] * weights[0] +
        merged_data['Normalized Word Count'] * weights[1] +
        merged_data['Translation Quality Score'] * weights[2] +
        merged_data['Frequency of Occurrence Score'] * weights[3]
    )
    return scores

# Objective function for Bayesian optimization
def objective(weights):
    weights = weights / np.sum(weights)  # Ensure weights sum to 1
    predicted_scores = calculate_goodness_scores(weights)
    loss = mean_squared_error(predicted_scores, merged_data['Rating'])
    return loss

# Define the search space
space = [Real(0, 1), Real(0, 1), Real(0, 1), Real(0, 1)]

# Perform Bayesian optimization
result = gp_minimize(objective, space, n_calls=100, random_state=0)

# Best weights and loss
best_weights = result.x / np.sum(result.x)
best_loss = result.fun

# Mapping weights to their respective features
weight_names = ['Combination Score', 'Normalized Word Count', 'Translation Quality Score', 'Frequency of Occurrence Score']
best_weights_named = dict(zip(weight_names, best_weights))

print(f"Best Weights: {best_weights_named}")
print(f"Best Loss: {best_loss}")
# Out:
# Best Weights: {'Combination Score': 0.08637652379821915, 'Normalized Word Count': 0.43002990156415366, 'Translation Quality Score': 0.21433350360059686, 'Frequency of Occurrence Score': 0.26926007103703026}
# Best Loss: 0.11420094950924083

# %% [markdown]
# ## Dr Kamlesh

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from skopt import gp_minimize
from skopt.space import Real

# Load the survey results
survey_results = pd.read_csv('survey_results.csv')  # Dentist's ratings
data = pd.read_csv('survey.csv')  # Your dataset with all the columns

# Map dentist's ratings to numeric values
rating_map = {'Good': 1, 'Moderate': 0.5, 'Bad': 0}
survey_results['Rating'] = survey_results['rating pcp'].map(rating_map)

# Merge survey results with your dataset on the concept name or identifier
merged_data = pd.merge(data, survey_results, left_on='English Term', right_on='concept')

# Function to calculate goodness scores
def calculate_goodness_scores(weights):
    scores = (
        merged_data['Combination Score'] * weights[0] +
        merged_data['Normalized Word Count'] * weights[1] +
        merged_data['Translation Quality Score'] * weights[2] +
        merged_data['Frequency of Occurrence Score'] * weights[3]
    )
    return scores

# Objective function for Bayesian optimization
def objective(weights):
    weights = weights / np.sum(weights)  # Ensure weights sum to 1
    predicted_scores = calculate_goodness_scores(weights)
    loss = mean_squared_error(predicted_scores, merged_data['Rating'])
    return loss

# Define the search space
space = [Real(0, 1), Real(0, 1), Real(0, 1), Real(0, 1)]

# Perform Bayesian optimization
result = gp_minimize(objective, space, n_calls=100, random_state=0)

# Best weights and loss
best_weights = result.x / np.sum(result.x)
best_loss = result.fun

# Mapping weights to their respective features
weight_names = ['Combination Score', 'Normalized Word Count', 'Translation Quality Score', 'Frequency of Occurrence Score']
best_weights_named = dict(zip(weight_names, best_weights))

print(f"Best Weights: {best_weights_named}")
print(f"Best Loss: {best_loss}")
# Out:
# Best Weights: {'Combination Score': 0.20169325928914209, 'Normalized Word Count': 0.4979151731231969, 'Translation Quality Score': 0.10861818897801598, 'Frequency of Occurrence Score': 0.19177337860964502}
# Best Loss: 0.13959970708119282
